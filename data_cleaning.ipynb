# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# read in data by borough and year, add year column, select target columns,
# concatenate by borough then concatenate for whole city with new index

boroughs = ["Bronx", "Brooklyn", "Manhattan", "Queens", "StatenIsland"]
city_df = []

for borough in boroughs:
    borough_df = []
    for Year in range(2003,2019):
        file_name= f"{Year}_{borough}.csv"
        file_path = Path(borough,borough,file_name)
        year_frame = pd.read_csv(file_path, index_col=False)
        year_frame = year_frame.assign(Year=Year)
        borough_df.append(year_frame)
    borough_df = pd.concat(borough_df)
    borough_df = borough_df[["Borough", "Neighborhood", "Building Class Category", "Address", "Apartment Number", 
                            "Zip Code", "Residential Units", 
                            "Land Square Feet", "Gross Square Feet", 
                            "Year", "Sale Price", "Sale Date"]]
    borough_df["Borough"] = borough
    city_df.append(borough_df)
    
city_df = pd.concat(city_df,ignore_index=True)

city_df.columns = city_df.columns.str.replace(' ','_')

city_df.head()
# Out:
#   Borough               Neighborhood  \
# 0   Bronx  BATHGATE
# 1   Bronx  BATHGATE
# 2   Bronx  BATHGATE
# 3   Bronx  BATHGATE
# 4   Bronx  BATHGATE
#
#                         Building_Class_Category  \
# 0  01  ONE FAMILY HOMES
# 1  01  ONE FAMILY HOMES
# 2  01  ONE FAMILY HOMES
# 3  01  ONE FAMILY HOMES
# 4  01  ONE FAMILY HOMES
#
#                                      Address Apartment_Number  Zip_Code  \
# 0  1848 WASHINGTON AVENUE                                       10457.0
# 1  412 EAST 179 STREET                                          10457.0
# 2  410 EAST 182 STREET                                          10457.0
# 3  441 EAST 178 STREET                                          10457.0
# 4  461 EAST 178 STREET                                          10457.0
#
#    Residential_Units  Land_Square_Feet  Gross_Square_Feet  Year  Sale_Price  \
# 0                1.0            2943.0             2128.0  2003    130000.0
# 1                1.0            1842.0             2048.0  2003    204000.0
# 2                1.0            1330.0             1460.0  2003    235000.0
# 3                1.0            1287.0             2378.0  2003    125500.0
# 4                1.0            1782.0             1548.0  2003    215000.0
#
#              Sale_Date
# 0  2003-05-27 00:00:00
# 1  2003-04-07 00:00:00
# 2  2003-07-24 00:00:00
# 3  2003-05-02 00:00:00
# 4  2003-05-14 00:00:00

# %%
city_df.Building_Class_Category.unique()
# Out:
# array(['01  ONE FAMILY HOMES                        ',
#        '02  TWO FAMILY HOMES                        ',
#        '03  THREE FAMILY HOMES                      ',
#        '05  TAX CLASS 1 VACANT LAND                 ',
#        '07  RENTALS - WALKUP APARTMENTS             ',
#        '10  COOPS - ELEVATOR APARTMENTS             ',
#        '14  RENTALS - 4-10 UNIT                     ',
#        '21  OFFICE BUILDINGS                        ',
#        '22  STORE BUILDINGS                         ',
#        '27  FACTORIES                               ',
#        '29  COMMERCIAL GARAGES                      ',
#        '30  WAREHOUSES                              ',
#        '31  COMMERCIAL VACANT LAND                  ',
#        '37  RELIGIOUS FACILITIES                    ',
#        '06  TAX CLASS 1 - OTHER                     ',
#        '32  HOSPITAL AND HEALTH FACILITIES          ',
#        '38  ASYLUMS AND HOMES                       ',
#        '41  TAX CLASS 4 - OTHER                     ',
#        '08  RENTALS - ELEVATOR APARTMENTS           ',
#        '09  COOPS - WALKUP APARTMENTS               ',
#        '12  CONDOS - WALKUP APARTMENTS              ',
#        '28  COMMERCIAL CONDOS                       ',
#        '13  CONDOS - ELEVATOR APARTMENTS            ',
#        '04  TAX CLASS 1 CONDOS                      ',
#        '36  OUTDOOR RECREATIONAL FACILITIES         ',
#        '26  OTHER HOTELS                            ',
#        '34  THEATRES                                ',
#        '35  INDOOR PUBLIC AND CULTURAL FACILITIES   ',
#        '33  EDUCATIONAL FACILITIES                  ',
#        '23  LOFT BUILDINGS                          ',
#        '17  CONDOPS                                 ',
#        '39  TRANSPORTATION FACILITIES               ',
#        '40  SELECTED GOVERNMENTAL FACILITIES        ',
#        '18  TAX CLASS 3 - UTILITY PROPERTIES        ',
#        '15  CONDOS - 2-10 UNIT RESIDENTIAL          ',
#        '11A CONDO-RENTALS                           ',
#        '24  TAX CLASS 4 - UTILITY BUREAU PROPERTIES ',
#        '                                            ',
#        '01  ONE FAMILY DWELLINGS                    ',
#        '02  TWO FAMILY DWELLINGS                    ',
#        '03  THREE FAMILY DWELLINGS                  ',
#        '43  CONDO OFFICE BUILDINGS                  ',
#        '46  CONDO STORE BUILDINGS                   ',
#        '44  CONDO PARKING                           ',
#        '17  CONDO COOPS                             ',
#        '47  CONDO NON-BUSINESS STORAGE              ',
#        '18  TAX CLASS 3 - UNTILITY PROPERTIES       ',
#        '11  SPECIAL CONDO BILLING LOTS              ',
#        '01 ONE FAMILY DWELLINGS                    ',
#        '02 TWO FAMILY DWELLINGS                    ',
#        '03 THREE FAMILY DWELLINGS                  ',
#        '07 RENTALS - WALKUP APARTMENTS             ',
#        '09 COOPS - WALKUP APARTMENTS               ',
#        '10 COOPS - ELEVATOR APARTMENTS             ',
#        '14 RENTALS - 4-10 UNIT                     ',
#        '21 OFFICE BUILDINGS                        ',
#        '22 STORE BUILDINGS                         ',
#        '27 FACTORIES                               ',
#        '29 COMMERCIAL GARAGES                      ',
#        '30 WAREHOUSES                              ',
#        '31 COMMERCIAL VACANT LAND                  ',
#        '37 RELIGIOUS FACILITIES                    ',
#        '04 TAX CLASS 1 CONDOS                      ',
#        '05 TAX CLASS 1 VACANT LAND                 ',
#        '06 TAX CLASS 1 - OTHER                     ',
#        '08 RENTALS - ELEVATOR APARTMENTS           ',
#        '41 TAX CLASS 4 - OTHER                     ',
#        '44 CONDO PARKING                           ',
#        '12 CONDOS - WALKUP APARTMENTS              ',
#        '17 CONDO COOPS                             ',
#        '33 EDUCATIONAL FACILITIES                  ',
#        '13 CONDOS - ELEVATOR APARTMENTS            ',
#        '32 HOSPITAL AND HEALTH FACILITIES          ',
#        '35 INDOOR PUBLIC AND CULTURAL FACILITIES   ',
#        '36 OUTDOOR RECREATIONAL FACILITIES         ',
#        '39 TRANSPORTATION FACILITIES               ',
#        '43 CONDO OFFICE BUILDINGS                  ',
#        '46 CONDO STORE BUILDINGS                   ',
#        '38 ASYLUMS AND HOMES                       ',
#        '40 SELECTED GOVERNMENTAL FACILITIES        ',
#        '34 THEATRES                                ',
#        '15 CONDOS - 2-10 UNIT RESIDENTIAL          ',
#        '01 ONE FAMILY DWELLINGS', '02 TWO FAMILY DWELLINGS',
#        '03 THREE FAMILY DWELLINGS', '05 TAX CLASS 1 VACANT LAND',
#        '06 TAX CLASS 1 - OTHER', '07 RENTALS - WALKUP APARTMENTS',
#        '08 RENTALS - ELEVATOR APARTMENTS', '09 COOPS - WALKUP APARTMENTS',
#        '10 COOPS - ELEVATOR APARTMENTS', '22 STORE BUILDINGS',
#        '26 OTHER HOTELS', '27 FACTORIES', '29 COMMERCIAL GARAGES',
#        '30 WAREHOUSES', '31 COMMERCIAL VACANT LAND',
#        '04 TAX CLASS 1 CONDOS', '14 RENTALS - 4-10 UNIT',
#        '21 OFFICE BUILDINGS', '41 TAX CLASS 4 - OTHER',
#        '12 CONDOS - WALKUP APARTMENTS',
#        '32 HOSPITAL AND HEALTH FACILITIES', '37 RELIGIOUS FACILITIES',
#        '42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC',
#        '43 CONDO OFFICE BUILDINGS', '46 CONDO STORE BUILDINGS',
#        '13 CONDOS - ELEVATOR APARTMENTS', '11A CONDO-RENTALS',
#        '44 CONDO PARKING', '35 INDOOR PUBLIC AND CULTURAL FACILITIES',
#        '38 ASYLUMS AND HOMES', '33 EDUCATIONAL FACILITIES',
#        '15 CONDOS - 2-10 UNIT RESIDENTIAL', '17 CONDO COOPS',
#        '28 COMMERCIAL CONDOS', '47 CONDO NON-BUSINESS STORAGE', nan,
#        '16  CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT ',
#        '25  LUXURY HOTELS                           ',
#        '49  CONDO WAREHOUSES/FACTORY/INDUS          ',
#        '42  CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC  ',
#        '48  CONDO TERRACES/GARDENS/CABANAS          ',
#        '45  CONDO HOTELS                            ',
#        '16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT ',
#        '47 CONDO NON-BUSINESS STORAGE              ',
#        '48 CONDO TERRACES/GARDENS/CABANAS          ',
#        '49 CONDO WAREHOUSES/FACTORY/INDUS          ',
#        '28 COMMERCIAL CONDOS                       ',
#        '42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC  ',
#        '26 OTHER HOTELS                            ',
#        '23 LOFT BUILDINGS                          ',
#        '45 CONDO HOTELS                            ',
#        '16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT',
#        '36 OUTDOOR RECREATIONAL FACILITIES',
#        '48 CONDO TERRACES/GARDENS/CABANAS', '23 LOFT BUILDINGS',
#        '25 LUXURY HOTELS', '45 CONDO HOTELS',
#        '49 CONDO WAREHOUSES/FACTORY/INDUS',
#        '25 LUXURY HOTELS                           ',
#        '11 SPECIAL CONDO BILLING LOTS              ', '34 THEATRES',
#        '40 SELECTED GOVERNMENTAL FACILITIES',
#        '39 TRANSPORTATION FACILITIES'], dtype=object)

# %%
# check if Residential_Units filters out non residential building class categories

# codes of unique building categories for whole df
total_cat = city_df.Building_Class_Category.str[:2].unique().tolist()

# codes of unique building categories where Residential_Units > 0
res_filtered = city_df[(city_df.Residential_Units > 0)]
res_filtered = res_filtered.Building_Class_Category.str[:2].unique().tolist()

# list of codes in total_cat not in res_filtered
res_class = [x for x in total_cat if x not in res_filtered]
print(res_class)
# Out:
# ['18', '24', '47', '42', nan, '49', '45']

# %%
# drop Residential_Units Column
city_df.drop('Residential_Units', axis=1, inplace=True)

# %%
# drop rows with sqf == 0, price < 1000
city_df = city_df[(city_df.Land_Square_Feet > 0) & (city_df.Gross_Square_Feet > 0) & (city_df.Sale_Price > 1000)]

# %%
# filter for target residential_classes
residential_classes = ["01", "02", "03", "04", "06", "07", "08", "09", "10", "11", 
                         "12", "13", "14", "15", "16", "17", "23", "45", "49"]
city_df = city_df[city_df["Building_Class_Category"].str[:2].isin(residential_classes)]

# %%
city_df.Building_Class_Category.unique()
# Out:
# array(['01  ONE FAMILY HOMES                        ',
#        '02  TWO FAMILY HOMES                        ',
#        '03  THREE FAMILY HOMES                      ',
#        '07  RENTALS - WALKUP APARTMENTS             ',
#        '14  RENTALS - 4-10 UNIT                     ',
#        '08  RENTALS - ELEVATOR APARTMENTS           ',
#        '09  COOPS - WALKUP APARTMENTS               ',
#        '06  TAX CLASS 1 - OTHER                     ',
#        '10  COOPS - ELEVATOR APARTMENTS             ',
#        '23  LOFT BUILDINGS                          ',
#        '11A CONDO-RENTALS                           ',
#        '17  CONDOPS                                 ',
#        '01  ONE FAMILY DWELLINGS                    ',
#        '02  TWO FAMILY DWELLINGS                    ',
#        '03  THREE FAMILY DWELLINGS                  ',
#        '01 ONE FAMILY DWELLINGS                    ',
#        '02 TWO FAMILY DWELLINGS                    ',
#        '03 THREE FAMILY DWELLINGS                  ',
#        '07 RENTALS - WALKUP APARTMENTS             ',
#        '14 RENTALS - 4-10 UNIT                     ',
#        '08 RENTALS - ELEVATOR APARTMENTS           ',
#        '09 COOPS - WALKUP APARTMENTS               ',
#        '10 COOPS - ELEVATOR APARTMENTS             ',
#        '06 TAX CLASS 1 - OTHER                     ',
#        '01 ONE FAMILY DWELLINGS', '02 TWO FAMILY DWELLINGS',
#        '03 THREE FAMILY DWELLINGS', '07 RENTALS - WALKUP APARTMENTS',
#        '14 RENTALS - 4-10 UNIT', '08 RENTALS - ELEVATOR APARTMENTS',
#        '13 CONDOS - ELEVATOR APARTMENTS', '04 TAX CLASS 1 CONDOS',
#        '12 CONDOS - WALKUP APARTMENTS',
#        '15 CONDOS - 2-10 UNIT RESIDENTIAL',
#        '13  CONDOS - ELEVATOR APARTMENTS            ',
#        '11  SPECIAL CONDO BILLING LOTS              ',
#        '23 LOFT BUILDINGS                          ',
#        '16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT', '23 LOFT BUILDINGS',
#        '06 TAX CLASS 1 - OTHER',
#        '12  CONDOS - WALKUP APARTMENTS              ',
#        '15  CONDOS - 2-10 UNIT RESIDENTIAL          ',
#        '17  CONDO COOPS                             ', '45 CONDO HOTELS',
#        '17 CONDO COOPS                             '], dtype=object)

# %%
# dataframe with upper and lower quantile for each borough and year
city_df["$sqf"] = city_df["Sale_Price"]/city_df["Gross_Square_Feet"]
lower_quant = city_df.groupby(["Borough", "Year"])["$sqf"].quantile(0.05)
upper_quant = city_df.groupby(["Borough", "Year"])["$sqf"].quantile(0.95)
quant_df = pd.concat([lower_quant, upper_quant], join="outer",axis=1, keys=["lower", "upper"])
quant_df.head()
# Out:
#                   lower       upper
# Borough Year
# Bronx   2003  37.943262  241.536458
#         2004  53.669085  290.591688
#         2005  60.522029  329.994289
#         2006  71.219426  353.150329
#         2007  60.995753  365.035366

# %%
# Adding columns with upper and lower $/sqf quantiles 
city_df["Lower_Quant"] = city_df.groupby(["Borough", "Year"])["$sqf"].transform(lambda x: x.quantile(0.05))
city_df["Upper_Quant"] = city_df.groupby(["Borough", "Year"])["$sqf"].transform(lambda x: x.quantile(0.95))
city_df.shape
# Out:
# (480509, 14)

# %%
# properties filtered out by quantiles
rejected = city_df[(city_df["$sqf"]<city_df["Lower_Quant"]) | (city_df["$sqf"]>city_df["Upper_Quant"])]
rejected.head()
# Out:
#     Borough               Neighborhood  \
# 66    Bronx  BATHGATE
# 67    Bronx  BATHGATE
# 146   Bronx  BAYCHESTER
# 161   Bronx  BAYCHESTER
# 164   Bronx  BAYCHESTER
#
#                           Building_Class_Category  \
# 66   03  THREE FAMILY HOMES
# 67   03  THREE FAMILY HOMES
# 146  01  ONE FAMILY HOMES
# 161  01  ONE FAMILY HOMES
# 164  01  ONE FAMILY HOMES
#
#                                        Address Apartment_Number  Zip_Code  \
# 66   2243 BATHGATE AVENUE                                         10457.0
# 67   2243 BATHGATE AVENUE                                         10457.0
# 146  1124 EAST 213 STREET                                         10469.0
# 161  3477 MICKLE AVENUE                                           10469.0
# 164  3466 MICKLE AVENUE                                           10469.0
#
#      Land_Square_Feet  Gross_Square_Feet  Year  Sale_Price  \
# 66             1562.0             4224.0  2003    125000.0
# 67             1562.0             4224.0  2003     35000.0
# 146            2145.0             1920.0  2003     11000.0
# 161            1918.0             1024.0  2003    259500.0
# 164            1879.0             1900.0  2003     25000.0
#
#                Sale_Date        $sqf  Lower_Quant  Upper_Quant
# 66   2003-06-02 00:00:00   29.592803    37.943262   241.536458
# 67   2003-06-02 00:00:00    8.285985    37.943262   241.536458
# 146  2003-11-17 00:00:00    5.729167    37.943262   241.536458
# 161  2003-04-30 00:00:00  253.417969    37.943262   241.536458
# 164  2003-08-28 00:00:00   13.157895    37.943262   241.536458

# %%
# Select values that fall between quantiles
city_df = city_df[(city_df["$sqf"]>city_df["Lower_Quant"]) & (city_df["$sqf"]<city_df["Upper_Quant"])]
city_df.shape
# Out:
# (432373, 14)

# %%
# of duplicated_addresses
duplicated_address = city_df["Address"][(city_df["Address"].duplicated()==True)]
duplicated_address.shape
# Out:
# (76502,)

# %%
# number of apartments can't fill duplicated addresses
apt_df = city_df["Apartment_Number"].unique()
apt_df.shape
# Out:
# (1325,)

# %%
city_df.drop(["Apartment_Number"], axis=1)
# Out:
#               Borough               Neighborhood  \
# 0               Bronx  BATHGATE
# 1               Bronx  BATHGATE
# 2               Bronx  BATHGATE
# 3               Bronx  BATHGATE
# 4               Bronx  BATHGATE
# ...               ...                        ...
# 1523242  StatenIsland                    WOODROW
# 1523244  StatenIsland                    WOODROW
# 1523247  StatenIsland                    WOODROW
# 1523248  StatenIsland                    WOODROW
# 1523251  StatenIsland                    WOODROW
#
#                               Building_Class_Category  \
# 0        01  ONE FAMILY HOMES
# 1        01  ONE FAMILY HOMES
# 2        01  ONE FAMILY HOMES
# 3        01  ONE FAMILY HOMES
# 4        01  ONE FAMILY HOMES
# ...                                               ...
# 1523242                       02 TWO FAMILY DWELLINGS
# 1523244                       02 TWO FAMILY DWELLINGS
# 1523247                       02 TWO FAMILY DWELLINGS
# 1523248                       02 TWO FAMILY DWELLINGS
# 1523251                       02 TWO FAMILY DWELLINGS
#
#                                            Address  Zip_Code  \
# 0        1848 WASHINGTON AVENUE                      10457.0
# 1        412 EAST 179 STREET                         10457.0
# 2        410 EAST 182 STREET                         10457.0
# 3        441 EAST 178 STREET                         10457.0
# 4        461 EAST 178 STREET                         10457.0
# ...                                            ...       ...
# 1523242                             20 POPLAR LANE   10309.0
# 1523244                        35 SALAMANDER COURT   10309.0
# 1523247                            64 DARNELL LANE   10309.0
# 1523248                            16 DARNELL LANE   10309.0
# 1523251                           65 PHEASANT LANE   10309.0
#
#          Land_Square_Feet  Gross_Square_Feet  Year  Sale_Price  \
# 0                  2943.0             2128.0  2003    130000.0
# 1                  1842.0             2048.0  2003    204000.0
# 2                  1330.0             1460.0  2003    235000.0
# 3                  1287.0             2378.0  2003    125500.0
# 4                  1782.0             1548.0  2003    215000.0
# ...                   ...                ...   ...         ...
# 1523242            2568.0             2700.0  2018    640000.0
# 1523244            2440.0             1300.0  2018    630000.0
# 1523247            3180.0             1300.0  2018    675000.0
# 1523248            4431.0             1300.0  2018    630000.0
# 1523251            3720.0             1850.0  2018    680000.0
#
#                    Sale_Date        $sqf  Lower_Quant  Upper_Quant
# 0        2003-05-27 00:00:00   61.090226    37.943262   241.536458
# 1        2003-04-07 00:00:00   99.609375    37.943262   241.536458
# 2        2003-07-24 00:00:00  160.958904    37.943262   241.536458
# 3        2003-05-02 00:00:00   52.775442    37.943262   241.536458
# 4        2003-05-14 00:00:00  138.888889    37.943262   241.536458
# ...                      ...         ...          ...          ...
# 1523242  2018-05-14 00:00:00  237.037037   157.701466   567.139001
# 1523244  2018-04-27 00:00:00  484.615385   157.701466   567.139001
# 1523247  2018-12-28 00:00:00  519.230769   157.701466   567.139001
# 1523248  2018-07-24 00:00:00  484.615385   157.701466   567.139001
# 1523251  2018-11-28 00:00:00  367.567568   157.701466   567.139001
#
# [432373 rows x 13 columns]

# %%
# checking for null values
na = city_df.set_index(["Borough"]).isna().sum(level=0)
na.head()
# Out:
#               Neighborhood  Building_Class_Category  Address  \
# Borough
# Bronx                    0                        0        0
# Brooklyn                 0                        0        0
# Manhattan                0                        0        0
# Queens                   0                        0        0
# StatenIsland             0                        0        0
#
#               Apartment_Number  Zip_Code  Land_Square_Feet  Gross_Square_Feet  \
# Borough
# Bronx                     3216         0                 0                  0
# Brooklyn                  6685         0                 0                  0
# Manhattan                  562         0                 0                  0
# Queens                    9976         0                 0                  0
# StatenIsland              4851         0                 0                  0
#
#               Year  Sale_Price  Sale_Date  $sqf  Lower_Quant  Upper_Quant
# Borough
# Bronx            0           0          0     0            0            0
# Brooklyn         0           0          0     0            0            0
# Manhattan        0           0          0     0            0            0
# Queens           0           0          0     0            0            0
# StatenIsland     0           0          0     0            0            0

# %%
city_df.reset_index(inplace=True)

# %%
address_df = city_df[["Address", "Building_Class_Category", "Borough", "Neighborhood", 
                     "Zip_Code"]]
sale_df = city_df[["Gross_Square_Feet", "Sale_Price", "Sale_Date", "Year"]]

# %%
sale_df.to_csv("NY_Propety_Sales_Table.csv")
address_df.to_csv("NY_Property_Address_Table.csv")

# %%
rejected.to_csv("Price_Outliers.csv")
